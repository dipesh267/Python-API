# %% [markdown]
# # Weather Analysis
#
# 1. As the Latitude increases, the temperature increases

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import random
import seaborn as sns
from pprint import pprint
from myKey import key
from citipy import citipy

# %%
x_coord = []
y_coord = []
for count in range(125):
    x_coord.append(random.randrange(0,180))
    x_coord.append(random.randrange(0,180))
    x_coord.append(random.randrange(0,180)*(-1))
    x_coord.append(random.randrange(0,180)*(-1))

for count in range(125):
    y_coord.append(random.randrange(0,90))
    y_coord.append(random.randrange(0,90))
    y_coord.append(random.randrange(0,90)*(-1))
    y_coord.append(random.randrange(0,90)*(-1))

cities_df = pd.DataFrame({
    'x' : x_coord,
    'y' : y_coord
})
print(len(cities_df))
print(cities_df.head())
# Out:
# 500
#      x   y
# 0   51  13
# 1   52  62
# 2 -133 -77
# 3  -76 -85
# 4  164  86

# %%
#get list of cities
cities = []
countries = []
for index, row in cities_df.iterrows():
    lon = float(row["x"])
    lat = float(row["y"])
    city = citipy.nearest_city(lat, lon)
    cities.append(city.city_name)
    countries.append(city.country_code.upper())
    
cities_df['city'] = cities
cities_df['country'] = countries

cities_df = cities_df.drop_duplicates('city')

print(len(cities_df))
print(cities_df.head())
# Out:
# 256
#      x   y       city country
# 0   51  13     bereda      SO
# 1   52  62  kortkeros      RU
# 2 -133 -77    rikitea      PF
# 3  -76 -85    ushuaia      AR
# 4  164  86   cherskiy      RU

# %%
url = "http://api.openweathermap.org/data/2.5/weather"
query_params = {
    'appid': key,
    'units': 'metric',
    'q': 'khatanga'
}
response = requests.get(url, params=query_params).json()
pprint(response)

print(response['coord']['lat'])
print(response['main']['temp'])
print(response['clouds']['all'])
print(response['main']['humidity'])
print(response['wind']['speed'])
print(response['coord']['lat'])
# Out:
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1528758086,
#  'id': 2022572,
#  'main': {'grnd_level': 1021.32,
#           'humidity': 51,
#           'pressure': 1021.32,
#           'sea_level': 1025.94,
#           'temp': 15.28,
#           'temp_max': 15.28,
#           'temp_min': 15.28},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'message': 0.0033, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 108.501, 'speed': 3.76}}
# 71.98
# 15.28
# 8
# 51
# 3.76
# 71.98

# %%
# Build URL
url = "http://api.openweathermap.org/data/2.5/weather"
query_params = {
    'appid': key,
    'units': 'metric'
}

cities = cities_df['city']

# set up lists to hold reponse info
lat = []
temp = []
cloud = []
humidity = []
wind_speed = []
error = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        query_params['q'] = city
        response = requests.get(url, params=query_params).json()
        #lat.append(response)
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        cloud.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
    except KeyError:
        lat.append('Error')
        temp.append('Error')
        cloud.append('Error')
        humidity.append('Error')
        wind_speed.append('Error')
        error.append(city)
        

cities_df['lat'] = lat
cities_df['temp'] = temp
cities_df['cloud'] = cloud
cities_df['humidity'] = humidity
cities_df['wind_speed'] = wind_speed 
print(cities_df.head())

#print(lat[0])
#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")
# Out:
#      x   y       city country    lat   temp cloud humidity wind_speed
# 0   51  13     bereda      SO  43.27     14    90      100        3.6
# 1   52  62  kortkeros      RU  61.81      2     0       93          2
# 2 -133 -77    rikitea      PF -23.12  24.73    56      100       9.76
# 3  -76 -85    ushuaia      AR -54.81      1    40       74          1
# 4  164  86   cherskiy      RU  68.75  14.28    20       57       2.96

# %%
#list of cities not found by API
print(error)
# Out:
# ['marcona', 'barentsburg', 'jaramana', 'samusu', 'amderma', 'pemangkat', 'vaitupu', 'nizhneyansk', 'arkhangelos', 'linchuan', 'kuche', 'hihifo', 'jinchengjiang', 'burkhala', 'sentyabrskiy', 'acin', 'dzhusaly', 'jiddah', 'yanan', 'tumannyy', 'cam pha', 'belushya guba']

# %%
#clean data by removing all 'Error'
#or just set any error as NaN in the DF and then run np.dropna from the numpy pkg.
cities_df = cities_df[cities_df['temp'] != 'Error']
print(len(cities_df))
print(cities_df.head())
# Out:
# 234
#      x   y       city country    lat   temp cloud humidity wind_speed
# 0   51  13     bereda      SO  43.27     14    90      100        3.6
# 1   52  62  kortkeros      RU  61.81      2     0       93          2
# 2 -133 -77    rikitea      PF -23.12  24.73    56      100       9.76
# 3  -76 -85    ushuaia      AR -54.81      1    40       74          1
# 4  164  86   cherskiy      RU  68.75  14.28    20       57       2.96

# %%
plt.scatter(cities_df["lat"], cities_df["temp"], marker="o")
#plt.scatter(cities_df["lat"], cities_df["cloud"], marker="o")
#plt.scatter(cities_df["lat"], cities_df["humidity"], marker="o")
#plt.scatter(cities_df["lat"], cities_df["wind_speed"], marker="o")
# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
plt.scatter(cities_df["lat"], cities_df["cloud"], marker="o")

plt.title("Cloudyness in World Cities")
plt.ylabel("Clouds")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %%
plt.scatter(cities_df["lat"], cities_df["humidity"], marker="o")

plt.title("Humidity in World Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %%
plt.scatter(cities_df["lat"], cities_df["wind_speed"], marker="o")

plt.title("Wind Speeds in World Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()
